# %%
import numpy as np

# %%
import requests
from bs4 import BeautifulSoup
url='https://www.heraldscotland.com/'
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.87 Safari/537.36'}
r = requests.get(url, headers = headers)
content = r.text
#print(content)

soup = BeautifulSoup(content, 'lxml')

#divs = soup.find_all(class_ = 'article block untagged mb15 typs_hot')

#print(divs)
#for div in divs:
 #   #joke = div.span.get_text()
  #  ID=div.select('h2')[0].text
 #   print(ID)
    
    #print(joke)
    #print('------')

# %% [markdown]
# # Time

# %%
from datetime import datetime
def time_transfer(time):
    ts = int(time)

    # if you encounter a "year is out of range" error the timestamp
    # may be in milliseconds, try `ts /= 1000` in that case
    return(datetime.utcfromtimestamp(ts).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# '2018-11-06 14:42:24'

# %% [markdown]
# # Content

# %% [markdown]
# def news_content(news_url,a,b):
#     content1=[]
#     res = requests.get(news_url, headers = headers)
#     res.encoding = 'utf-8'
#
#     soup = BeautifulSoup(res.text, 'lxml')
# #print(soup)
#     for articles in soup.select(a):
#         if(len(articles.select(b)) > 0):
#             for i in range(len(articles.select(b))):
#                 ab=articles.select(b)[i].text
#                 content1.append(ab)
#                 return(content1)

# %% [markdown]
# res = requests.get('https://www.heraldscotland.com/news/17189225.poorest-university-students-saddled-with-largest-debts/', headers = headers)
# res.encoding = 'utf-8'
# soup = BeautifulSoup(res.text, 'lxml')
# for articles in soup.select('.article-body'):
#     if(len(articles.select('p')) > 5):
#         for j in range(5):
#             ab=articles.select('p')[j].text
#             print(ab)
#
#     else:
#         for i in range(len(articles.select('p'))):
#             ab1=articles.select('p')[i].text
#             print(ab1)

# %%
def news_content(news_url,a,b):
    c=[]
    c1=[]
    res = requests.get(news_url, headers = headers)
    res.encoding = 'utf-8'

    soup = BeautifulSoup(res.text, 'lxml')
#print(soup)
    for articles in soup.select(a):
        if(len(articles.select(b)) > 5):
            for j in range(5):
                ab=articles.select(b)[j].text
                c.append(ab)
                print(ab)
            return(c)
        else:
            for i in range(len(articles.select(b))):
                ab1=articles.select(b)[i].text
                c1.append(ab1)
                print(ab1)
            return(c1)

# %% [markdown]
# # Title&URL

# %%
article_url=[]
article_title=[]
for head in soup.select('.h1 a'):
    head=title[0]
    headtitle=title[0].text
    print(headtitle,'\n')
    print(url[:-1]+head['href'],'\n')
    article_url.append(url[:-1]+head['href'])
    article_title.append(headtitle)
for news in soup.select('.nq-article-card'): 
    if(len(news.select('h2'))> 0):
        h2 = news.select('h2')[0].text
        #title=soup.select('title')[0].text
        a=news.select('a')[0]
        b=url[:-1]+a['href']
        #con=news_content(url[:-1]+a['href'],'.article-body','p')
        print(h2,'\n')
        print(url[:-1]+a['href'],'\n')
        article_url.append(b)
        article_title.append(h2)
len(article_url)
len(article_title)
# Out:
# US midterm election: What to look out for as results roll in
#
# https://www.heraldscotland.com/news/17205474.when-will-us-midterm-election-results-come-in-heres-what-to-expect-from-vote/
#
# Proposed 'meat tax' health levy would add 79% to cost of bacon
#
# https://www.heraldscotland.com/news/17205263.charge-shoppers-79-more-for-bacon-say-scientists-behind-life-saving-meat-tax/
#
# Campaigners say Scots justice system 'fails' rape victims as they launch bid to scrap corroboration
#
# https://www.heraldscotland.com/news/17205343.campaigners-say-scots-justice-system-fails-rape-victims-as-they-launch-bid-to-scrap-corroboration/
#
# Scottish Government confirms misconduct complaint against Alex Salmond dealt with in 2013
#
# https://www.heraldscotland.com/news/17204701.scottish-government-confirms-misconduct-complaint-against-alex-salmond-dealt-with-in-2013/
#
# Neil Mackay: Darkness will descend all over the West if Trump wins tonight
#
# ...

# %% [markdown]
# # Timeline
#  https://stackoverflow.com/questions/3682748/converting-unix-timestamp-string-to-readable-date

# %%
article_time=[]
for news_time in soup.select('.formatTimeStampEs6'):
    time=(news_time)['data-timestamp']
    print(time)
    print(time_transfer(time))
    article_time.append(time_transfer(time))

len(article_time)
# Out:
# 1541535299
# 2018-11-06 20:14:59
# 1541528773
# 2018-11-06 18:26:13
# 1541528120
# 2018-11-06 18:15:20
# 1541526782
# 2018-11-06 17:53:02
# 1541522389
# 2018-11-06 16:39:49
# 1541480536
# 2018-11-06 05:02:16
# 1541510442
# 2018-11-06 13:20:42
# 1541480400
# 2018-11-06 05:00:00
# 1541503417
# 2018-11-06 11:23:37
# 1541501381
# 2018-11-06 10:49:41
# 1541535517
# 2018-11-06 20:18:37
# 1541507238
# 2018-11-06 12:27:18
# 1541506528
# 2018-11-06 12:15:28
# 1541508671
# 2018-11-06 12:51:11
# 1541519328
# 2018-11-06 15:48:48
# 1541517997
# 2018-11-06 15:26:37
# 1541532295
# 2018-11-06 19:24:55
# 1541500357
# 2018-11-06 10:32:37
# 1541532334
# 2018-11-06 19:25:34
# 1541514099
# 2018-11-06 14:21:39
# 1541509480
# 2018-11-06 13:04:40
# 1541507813
# 2018-11-06 12:36:53
# 1541455200
# 2018-11-05 22:00:00
# 1541502686
# 2018-11-06 11:11:26
# 1541488382
# 2018-11-06 07:13:02
# 1541500970
# 2018-11-06 10:42:50
# 1541498974
# 2018-11-06 10:09:34
# 1541444516
# 2018-11-05 19:01:56
# 1541485489
# ...

# %%
len(soup.select('.formatTimeStampEs6'))
# Out:
# 92

# %% [markdown]
# # URL&Content

# %%
article_content=[]
for url_ in article_url:
    print('article from:',url_)
    k=news_content(url_,'.article-body','p')
    article_content.append(k)
# Out:
# article from: https://www.heraldscotland.com/news/17205474.when-will-us-midterm-election-results-come-in-heres-what-to-expect-from-vote/
#
# Donald Trump's presidency has been a turbulent ride for America and the wider world.
#
#
#   Today Americans have a chance to deliver their verdict on Mr Trump's two years in office in the US midterm elections.
#
#
#   At stake is the Republicans' control of US congress - comprising the house of representatives and the upper chamber, the US senate - along with the party's command of governors' offices and statehouses around the country.
#
#
# Read more: Donald Trump and the battle for America's soul: David Pratt on the mother of all Midterm elections
#
#
#   Polls start closing at 6pm EST in Kentucky (11pm GMT), but things will really start rolling at 7pm (midnight GMT), when polls close in Georgia, Indiana, South Carolina and Virginia.
#
# ...

# %%
len(article_content)
# Out:
# 91

# %% [markdown]
# # Print (Title, Time, URL)

# %%
#if (len(article_title)==len(article_time)):
for i in range(0,len(article_title)):
    print(article_title[i])
    print(article_time[i+1])
    print(article_url[i])
    print(article_content[i])

#else:
    #print('fitting error')
# Out:
# Campaigners say Scots justice system 'fails' rape victims as they launch bid to scrap corroboration
# 2018-11-06 17:53:02
# https://www.heraldscotland.com/news/17205343.campaigners-say-scots-justice-system-fails-rape-victims-as-they-launch-bid-to-scrap-corroboration/
# ['\n  Women who believe the Scottish legal system has allowed men accused of raping them to escape justice are calling for the rule of ‘corroboration’ to be scrapped.\n', '\n  Shirley Ross, 40, and Emma Bryson, 46, along with three other women who remain anonymous - are demanding a change, saying the current system has “failed” them.\n', '\n  Each of the five women was denied the chance of having their alleged abuser prosecuted due to the legal requirement for corroboration.\n', "\nRead more:\xa0Kenny McAskill: rule of corroboration 'has failed'\n", '\n  It requires two independent pieces of evidence before a case can go to court.\n']
# ...

# %%
#as(article_content[0])      
#" ".join(str(x) for x in article_content[0])
len(article_url)
len(article_time)
len(article_title)
len(article_content)
# Out:
# 91

# %%
f = open("C:/Users/User/Desktop/The Herald_news.txt", "w", encoding="utf-8")
f.write(str(len(article_title))+ " News are collected"+'\n')
for i in range(0,len(article_title)):
    f.write(article_title[i]+'\n')
    f.write(article_time[i+1]+'\n')
    f.write(article_url[i]+'\n')
    f.write(" ".join(str(x) for x in article_content[i])+'\n')
f.close()

# %% [markdown]
# # Document

# %% [raw]
# # from bs4 import BeautifulSoup
# html_sample = ' \
#  <html> \
#  <body> \
#  <h1 id="title">Hello World</h1> \
#  <a href="#" class="link">This is link1</a> \
#  <a href="# link2" class="link">This is link2</a> \
#  </body> \
#  </html>'
#
# soup = BeautifulSoup(html_sample, 'lxml')
# #print(soup.text)
# soup = BeautifulSoup(html_sample)
# header = soup.select('h1')
# #print(header)
# #print(header[0])
# #print(header[0].text)
#
# alink = soup.select('a')
# #print(alink)
# for link in alink:
#     print(link)
#     print(link.txt)
#
# alink = soup.select('#title')
# print(alink)
#
# soup = BeautifulSoup(html_sample)
# for link in soup.select('.link'):
#     print(link)
#
#
# alinks = soup.select('a')
# for link in alinks:
#     print('----',link['href']) # 原理：會把標籤的屬性包裝成字典
